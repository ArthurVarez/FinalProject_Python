# %%
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataset = pd.read_csv('drug_consumption.csv')
data= dataset.copy()

# %% [markdown]
# ## Describing the dataset

# %%
#first we want to have a preview of our dataset
dataset
# Out:
#         ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0        1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1        2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2        3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3        4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4        5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...    ...      ...      ...        ...      ...        ...      ...      ...
# 1880  1884 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881  1885 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882  1886 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883  1887 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884  1888 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
# ...

# %%
dataset.describe()
# Out:
#                 ID         Age       Gender    Education      Country  \
# count  1885.000000  1885.00000  1885.000000  1885.000000  1885.000000
# mean    945.294960     0.03461    -0.000256    -0.003806     0.355542
# std     545.167641     0.87836     0.482588     0.950078     0.700335
# min       1.000000    -0.95197    -0.482460    -2.435910    -0.570090
# 25%     474.000000    -0.95197    -0.482460    -0.611130    -0.570090
# 50%     946.000000    -0.07854    -0.482460    -0.059210     0.960820
# 75%    1417.000000     0.49788     0.482460     0.454680     0.960820
# max    1888.000000     2.59171     0.482460     1.984370     0.960820
#
#          Ethnicity       Nscore       Escore       Oscore       Ascore  \
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# mean     -0.309577     0.000047    -0.000163    -0.000534    -0.000245
# std       0.166226     0.998106     0.997448     0.996229     0.997440
# ...

# %%
#shape of the dataset 
dataset.shape
# Out:
# (1885, 32)

# %%
#columns of the dataset 
dataset.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Nscore',
#        'Escore', 'Oscore', 'Ascore', 'Cscore', 'Impulsive', 'SS', 'Alcohol',
#        'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
#        'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
#        'Nicotine', 'Semer', 'VSA'],
#       dtype='object')

# %% [markdown]
# list of features : ['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Nscore',
#        'Escore', 'Oscore', 'Ascore', 'Cscore', 'Impulsive', 'SS', 'Alcohol',
#        'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
#        'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
#        'Nicotine', 'Semer', 'VSA'],

# %% [markdown]
# may be the response could be implusive

# %% [markdown]
# ### We need to discuss a bit about the features :
#     - ID : number of record in original database
#     - Age : Age of the of paticipants
#     - Gender : Gender of the paticipant ( 0.48246 -> Female , -0.48246 -> Male)
#     - Eduaction : Levele of education :
#         -2.43591 Left school before 16
#         -1.73790 Left school at 16 years
#         -1.43719 Left school at 17 years
#         -1.22751 Left school at 18 years
#         -0.61113 Some college or university, no certificate or degree
#         -0.05921 Professional certificate/ diploma
#         -0.45468 University degree
#         -1.16365 Masters degree
#         -1.98437 Doctorate degree
#     - Country: current residence country :
#         -0.09765 Australia
#         -0.24923 Canada
#         -0.46841 New Zealand
#         -0.28519 Other
#         -0.21128 Republic of Ireland
#         -0.96082 UK
#         -0.57009 USA
#     - Ethnicity : ethnicity of participants:
#         -0.50212 Asian
#         -1.10702 Black
#         -1.90725 Mixed-Black/Asian
#         -0.12600 Mixed-White/Asian
#         -0.22166 Mixed-White/Black
#         -0.11440 Other
#         -0.31685 White
#     -Nscore is NEO-FFI-R Neuroticism
#     -Escore is NEO-FFI-R Extraversion
#     -Oscore is NEO-FFI-R Openness to experience
#     -Ascore is NEO-FFI-R Agreeableness
#     -Cscore is NEO-FFI-R Conscientiousness
#     -Impulsive is impulsiveness measured by BIS-11
#     -SS is sensation seeing measured by ImpSS
#
#      for the 7 previous ones, features are nurmerical, they describes score. The higher your score, the more you'll be.
#
#      for the last one the features are categoricals.
#      CLO :  Never Used
#      CL1 : Used over a Decade Ago
#      CL2 : Used in Last Decade
#      CL3 : Used in Last Year
#      CL4 : Used in Last Month
#      CL5 : Used in Last Week
#      CL6 : Used in Last Day

# %%
#we want also to see the types of the features
dataset.dtypes
# Out:
# ID             int64
# Age          float64
# Gender       float64
# Education    float64
# Country      float64
# Ethnicity    float64
# Nscore       float64
# Escore       float64
# Oscore       float64
# Ascore       float64
# Cscore       float64
# Impulsive    float64
# SS           float64
# Alcohol       object
# Amphet        object
# Amyl          object
# Benzos        object
# Caff          object
# Cannabis      object
# Choc          object
# Coke          object
# Crack         object
# Ecstasy       object
# Heroin        object
# Ketamine      object
# Legalh        object
# LSD           object
# Meth          object
# Mushrooms     object
# Nicotine      object
# Semer         object
# VSA           object
# dtype: object

# %%
dataset.isna().sum()
# Out:
# ID           0
# Age          0
# Gender       0
# Education    0
# Country      0
# Ethnicity    0
# Nscore       0
# Escore       0
# Oscore       0
# Ascore       0
# Cscore       0
# Impulsive    0
# SS           0
# Alcohol      0
# Amphet       0
# Amyl         0
# Benzos       0
# Caff         0
# Cannabis     0
# Choc         0
# Coke         0
# Crack        0
# Ecstasy      0
# Heroin       0
# Ketamine     0
# Legalh       0
# LSD          0
# Meth         0
# Mushrooms    0
# Nicotine     0
# Semer        0
# VSA          0
# dtype: int64

# %% [markdown]
# no missing values is columns -> we don't need to delete somes rows

# %% [markdown]
# ### Previously we saw we had some categorical values by studying on the Dataset , let's convert the features

# %%
categoricals = ['Age', 'Gender', 'Education', 'Country'
                , 'Ethnicity', 'Alcohol'
                , 'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis'
                , 'Choc', 'Coke', 'Crack', 'Ecstasy', 'Heroin'
                , 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms', 'Nicotine', 'Semer', 'VSA']
numericals = list(set(dataset.columns)-set(categoricals))
numericals.remove('ID')
numericals
# Out:
# ['Cscore', 'Oscore', 'SS', 'Ascore', 'Impulsive', 'Nscore', 'Escore']

# %%
dataset.shape
# Out:
# (1885, 32)

# %% [markdown]
# let's try to replace some values by their meanings

# %%
dataset["Gender"].unique()
d = dict(zip(dataset["Gender"].unique(),["Female","Male"]))
dataset["Gender"].replace(d,inplace=True)

# %%
#replacing age categories 

temp=dict(zip(dataset["Age"].unique(),["35-44","25-34","18-24","65+","45-54","55-64"]))
dataset["Age"].replace(temp,inplace=True)

# %%
data["Education"].unique()
# Out:
# array([-0.05921,  1.98437,  1.16365, -1.22751, -1.7379 ,  0.45468,
#        -0.61113, -2.43591, -1.43719])

# %%
#Replacing education
temp=dict(zip(dataset["Education"].unique(),["Professional Deg","Doctorate Deg",
                                             "Master Deg","18 Left","16 Left","Uni Deg",
                                            "Uni No Deg","-16 Left","17 Left"]))
dataset["Education"].replace(temp,inplace=True)

# %%
#replacing Countries
temp=dict(zip(list(dataset["Country"].unique()),["UK","Canada","USA","Other","Australia","Ireland" ,
    "NZ " ]))
dataset["Country"].replace(temp,inplace=True)

# %%
dataset["Country"].value_counts()
# We can see we have the sames stats -> successfull replacement
# Out:
# UK           1044
# USA           557
# Other         118
# Canada         87
# Australia      54
# Ireland        20
# NZ              5
# Name: Country, dtype: int64

# %%
#Replacing ethnicity
temp=dict(zip(dataset["Ethnicity"].unique(),
              ["White/Asian","White","Other","White/Black","Asian","Black","Black/Asian"]))
dataset["Ethnicity"].replace(temp,inplace=True)

# %%
dataset[categoricals] = dataset[categoricals].astype("category")
dataset[numericals] = dataset[numericals].astype("float")
dataset.dtypes
# Out:
# ID              int64
# Age          category
# Gender       category
# Education    category
# Country      category
# Ethnicity    category
# Nscore        float64
# Escore        float64
# Oscore        float64
# Ascore        float64
# Cscore        float64
# Impulsive     float64
# SS            float64
# Alcohol      category
# Amphet       category
# Amyl         category
# Benzos       category
# Caff         category
# Cannabis     category
# Choc         category
# Coke         category
# Crack        category
# Ecstasy      category
# Heroin       category
# Ketamine     category
# Legalh       category
# LSD          category
# Meth         category
# Mushrooms    category
# Nicotine     category
# Semer        category
# VSA          category
# dtype: object

# %%
dataset["Ethnicity"].value_counts()
#successfull replacement too
# Out:
# White          1720
# Other            63
# Black            33
# Asian            26
# White/Black      20
# White/Asian      20
# Black/Asian       3
# Name: Ethnicity, dtype: int64

# %%
dataset.nunique()
# Out:
# ID           1885
# Age             6
# Gender          2
# Education       9
# Country         7
# Ethnicity       7
# Nscore         49
# Escore         42
# Oscore         35
# Ascore         41
# Cscore         41
# Impulsive      10
# SS             11
# Alcohol         7
# Amphet          7
# Amyl            7
# Benzos          7
# Caff            7
# Cannabis        7
# Choc            7
# Coke            7
# Crack           7
# Ecstasy         7
# Heroin          7
# Ketamine        7
# Legalh          7
# LSD             7
# Meth            7
# Mushrooms       7
# Nicotine        7
# Semer           5
# VSA             7
# dtype: int64

# %%
dataset["Semer"].unique()
# Out:
# [CL0, CL2, CL3, CL4, CL1]
# Categories (5, object): [CL0, CL2, CL3, CL4, CL1]

# %% [markdown]
# ### Ok, so now let's try to visualise the datas

# %%
# see proportions of the First 5 features


sns.countplot(dataset["Gender"])
# we have almost the same number of male and female in our dataset

# %%
# visualize the proportions of current residence country 

sns.countplot(dataset["Country"])
#UK and USA are the most represented here

# %%
#Same thing for ethnicity 

sns.countplot(dataset["Ethnicity"])

#huge proportion of participants are white

# %%
# Now, let's try to visualise the distribution of dimensions of NEO Personality Inventory on our sample.

NEO = list(set(numericals)-set(['SS','Impulsive']))

n = len(NEO)
i=0
fig, axes = plt.subplots(1, n, figsize=(15, 4), sharey=True)
for element in NEO:
    sns.distplot(dataset[element], ax=axes[i])
    i+=1

# %% [markdown]
# Score seems to be distibuted like a Normal distibution -> need to scale or not ?

# %%
# for SS and implusive 

SS_IMP = ['SS','Impulsive']

fig , axes = plt.subplots(1,2,figsize = (15,4))
i=0
for element in SS_IMP:
    sns.distplot(dataset[element],ax=axes[i])
    i+=1

# %%
# visualition for the drugs

fig , axes = plt.subplots(6,3,figsize=(20,20))
drugs = ['Alcohol',
       'Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
       'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms',
       'Nicotine', 'Semer', 'VSA']
c=0
for i in range(6):
    for j in range(3):
        sns.countplot(dataset[drugs[c]],ax=axes[i][j])
        c+=1

# %% [markdown]
# we can see that "legal" or "almost-legal" drugs are highly use (caf,choc, nicotine, canibis,legalh, benzos)
#
# May be we could try to classify drugs into two subparts such as legal an not legal ?
#
# May be it could help to see the influence of the law about drug consumption s
#
# May be we can visualise the proportions of user and non user for each drug too

# %%
#user vs non user for each drug
fig , axes = plt.subplots(6,3,figsize=(20,20))
e =0
for i in range(6):
    for j in range(3):
        x = drugs[e]
        element = [ 'Not User' if e=="CL0" else 'User'for e in dataset[x] ]
        s = pd.DataFrame(element,columns = [x])
        sns.countplot(s[x],ax = axes[i,j])
        e+=1

# %% [markdown]
# We can see the that legals drugs have been a lot used at least one time.
# People seems to be reluctant to experience hard drugs such as meh , heroine, ketamine , crack.

# %%
#proportion of user for each etnhicity and for each drug
fig , axes = plt.subplots(6,3,figsize=(30,30))
e=0
for i in range(6):
    for j in range(3):
        x = drugs[e]
        temp=dataset.groupby("Ethnicity")[x].apply(lambda x : x[x!="CL0"].count()/len(x) )
        sns.barplot(x=temp.index,y=temp.values,ax=axes[i,j])
        axes[i,j].set_title(x)
        e+=1

# %%
dataset.Ethnicity.value_counts()
# Out:
# White          1720
# Other            63
# Black            33
# Asian            26
# White/Black      20
# White/Asian      20
# Black/Asian       3
# Name: Ethnicity, dtype: int64

# %% [markdown]
# we have a lot of white people here , even if we can visualize proportion I don't think they are a really relevant.

# %%
#users eduaction repartition for each drug
fig , axes = plt.subplots(6,3,figsize=(35,35))
e =0
for i in range(6):
    for j in range(3):
        x = drugs[e]
        temp=dataset.groupby("Education")[x].apply(lambda x : x[x!="CL0"].count()/len(x) )
        sns.barplot(x=temp.index,y=temp.values,ax=axes[i,j])
        axes[i,j].set_title(x)
        e+=1

# %% [markdown]
# Ok , that's a nice visualtion to the the distibution of user study background of each drug

# %%
dataset.Education.value_counts()
# Out:
# Uni No Deg          506
# Uni Deg             480
# Master Deg          283
# Professional Deg    270
# 18 Left             100
# 16 Left              99
# Doctorate Deg        89
# 17 Left              30
# -16 Left             28
# Name: Education, dtype: int64

# %%
fig , axes = plt.subplots(6,3,figsize=(35,35))
e =0
for i in range(6):
    for j in range(3):
        x = drugs[e]
        temp=dataset.groupby("Gender")[x].apply(lambda x : x[x!="CL0"].count())
        sns.barplot(x=temp.index,y=temp.values,ax=axes[i,j])
        axes[i,j].set_title(str(x)+", total User : {}".format(temp.values[1]+temp.values[0]))
        e+=1

# %% [markdown]
# It seems that mens are more likely to experiment drugs.

# %%
from sklearn.preprocessing import LabelEncoder

col =list(dataset[drugs])
for c in col:
    le = LabelEncoder()
    data[c] = le.fit_transform( data[c])

# %%
data.drop("ID",axis=1,inplace=True)

# %%
data
# Out:
#           Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0     0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1    -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2     0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3    -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4     0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...       ...      ...        ...      ...        ...      ...      ...
# 1880 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore   Cscore  ...  Ecstasy  Heroin  Ketamine  Legalh  LSD  \
# ...

# %%
corrmat = data.corr()

plt.figure(figsize=(20,20))


sns.heatmap(corrmat,cmap = 'RdYlGn',annot=True,
             yticklabels = data.columns, xticklabels = data.columns)
plt.xticks(rotation=50)

plt.title("Correlation B/W Different Features",fontsize=18)
plt.show()

# %% [markdown]
# we can see there a strong correlation for some drugs, it could be expected because if you have experienced some hard drugs you are more likely to experienced others.

# %% [markdown]
# Now it's to time to build a prediction model to evaluate consommation of Cannabis knowing score and informations on a person.

# %% [markdown]
# # KNN

# %%
features = ['Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Nscore',
       'Escore', 'Oscore', 'Ascore', 'Cscore', 'Impulsive', 'SS']
target = ["Cannabis"]

# %%
from sklearn.model_selection import train_test_split
X = data[features]
y = data[target].astype("category")


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score
from sklearn.neighbors import KNeighborsClassifier
mod = KNeighborsClassifier()
mod.fit(X_train,y_train.values.ravel())
pred = mod.predict(X_test)
accuracy_score(y_test,pred)
# Out:
# 0.33687002652519893

# %% [markdown]
# Trying to know which is the best number of neigbhours

# %%
from sklearn.neighbors import KNeighborsClassifier


graph= dict()
for i in range(1,100):
    temp = KNeighborsClassifier(n_neighbors=i)
    temp.fit(X_train,y_train.values.ravel())
    pred_temp = temp.predict(X_test)
    
    graph[i]=accuracy_score(y_test,pred_temp)
    
x=list(graph.keys())
y=list(graph.values())
plt.plot(x,y)
sorted_d = sorted(graph.items(), key=lambda x: x[1],reverse=True)
sorted_d[0]
# Out:
# (65, 0.4005305039787798)

# %%
from sklearn.metrics import confusion_matrix
knn = KNeighborsClassifier(sorted_d[0][0])
knn.fit(X_train,y_train.values.ravel())
final_pred = knn.predict(X_test)

sns.heatmap(confusion_matrix(y_test,final_pred),annot=True)
print(accuracy_score(y_test,final_pred))
# Out:
# 0.4005305039787798

# %% [markdown]
# we can see that our accuracy score is not really good. Let's try to create a new feature User_Cannabis

# %%
element = [ 'Not User' if e=="CL0" else 'User'for e in dataset["Cannabis"] ]
element
# Out:
# ['Not User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'Not User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'Not User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'User',
#  'Not User',
#  'User',
#  'Not User',
#  'User',
#  'Not User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'User',
#  'User',
#  'Not User',
#  'User',
#  'User',
#  'Not User',
#  'User',
#  'User',
#  'Not User',
#  'Not User',
#  'Not User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'User',
#  'Not User',
#  'User',
#  'User',
#  'User',
#  'Not User',
#  'Not User',
#  'User',
#  'Not User',
#  'User',
#  'User',
# ...

# %%
data["User_Canna"]= element

# %%
data.replace({"User":True,'Not User':False},inplace=True)

# %%
data.User_Canna.value_counts()
# Out:
# True     1472
# False     413
# Name: User_Canna, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X2 = data[features]
y2 = data["User_Canna"]


X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.20)

# %%
from sklearn.neighbors import KNeighborsClassifier


graph= dict()
for i in range(1,100):
    temp = KNeighborsClassifier(n_neighbors=i)
    temp.fit(X_train2,y_train2.values.ravel())
    pred_temp = temp.predict(X_test2)
    
    graph[i]=accuracy_score(y_test2,pred_temp)
    
x=list(graph.keys())
y=list(graph.values())
plt.plot(x,y)
sorted_d = sorted(graph.items(), key=lambda x: x[1],reverse=True)
sorted_d[0]
# Out:
# (83, 0.8196286472148541)

# %%
kfinal = KNeighborsClassifier(sorted_d[0][0])
kfinal.fit(X_train2,y_train2.values.ravel())
yfinal = kfinal.predict(X_test2)
precision_score(yfinal,y_test2)
# Out:
# 0.9235880398671097

# %%
sns.heatmap(confusion_matrix(y_test2,yfinal),annot=True)

print(precision_score(yfinal,y_test2),accuracy_score(yfinal,y_test2))
# Out:
# 0.9235880398671097 0.8090185676392573

# %% [markdown]
# prediction is much better

# %% [markdown]
# # Random Forrest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train2,y_train2.values.ravel())
rdpredict=rf.predict(X_test2)
precision_score(rdpredict,y_test2)
# Out:
# 0.9169435215946844

# %% [markdown]
# searching the best number of tree to use like we did for knn

# %%
rep = dict()
for i in range (10,1000, 10):
    rf = RandomForestClassifier(i)
    rf.fit(X_train2,y_train2.values.ravel())
    rdpredict=rf.predict(X_test2)
    rep[i]= precision_score(rdpredict,y_test2)
plt.plot(list(rep.keys()),list(rep.values()))

# %%
max_acc = sorted(rep.items(), key=lambda x: x[1],reverse=True)[0]
max_acc[0]
# Out:
# 200

# %%
rfinal = RandomForestClassifier(n_estimators=max_acc[0])
rf.fit(X_train2,y_train2.values.ravel())
rdpredict=rf.predict(X_test2)
precision_score(rdpredict,y_test2)
# Out:
# 0.9269102990033222

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
Lr = LogisticRegression(max_iter=100)
Lr.fit(X_train2,y_train2)
p = Lr.predict(X_test2)
precision_score(p,y_test2)
# Out:
# 0.9169435215946844

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBC = GradientBoostingClassifier()
GBC.fit(X_train2,y_train2)
pred_GBC = GBC.predict(X_test2)
precision_score(pred_GBC,y_test2)
# Out:
# 0.9003322259136213

# %%
models = ["KNN",
"Random Forrest",
"Logistic Regression",
"Gradient Boosting"]
precisions = [precision_score(yfinal,y_test2),
precision_score(rdpredict,y_test2),
precision_score(p,y_test2),
precision_score(pred_GBC,y_test2)]
accuracies = [accuracy_score(yfinal,y_test2),
accuracy_score(rdpredict,y_test2),
accuracy_score(p,y_test2),
accuracy_score(pred_GBC,y_test2)]
df = pd.DataFrame(zip(models,precisions,accuracies),columns=["Model","Prec","Acc"])

# %%
fig , axes = plt.subplots(1,2,figsize=(20,5
                                      ))
sns.barplot(x=df["Model"], 
            y=df["Prec"],
            ax=axes[0],palette="Greens_d"
            
            )
axes[0].set_title("Precision comparaison for each model")

for ax in axes:
    
    for p in ax.patches:
        h = p.get_height()
        ax.text(p.get_x() + (p.get_width()/2), h*2.75/3, '{}'.format(round(h,3)), ha='center', color='black')
sns.barplot(x=df["Model"], 
            y=df["Acc"],
            ax=axes[1]
            ,palette="Greens_d"
            )
axes[1].set_title("Accuracy comparaison for each model")


for ax in axes:
    
    for p in ax.patches:
        h = p.get_height()
        ax.text(p.get_x() + (p.get_width()/2), h*2.75/3, '{}'.format(round(h,3)), ha='center', color='black')

# %% [markdown]
# we can see that random forrest is the best compromise to deal with precision an accuracy

# %%
# let's see the confusion matrix for random forrest
sns.heatmap(confusion_matrix(y_test2,rdpredict),annot=True, cmap="Reds")

# %% [markdown]
# # Improving the random Forrest model

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 990,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}
